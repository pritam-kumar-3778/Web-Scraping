# %%
import requests

URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

# %%
res
# Out:
# <Response [200]>

# %%
with open("WS_Scrapped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
